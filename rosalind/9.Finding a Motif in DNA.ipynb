# %% [markdown]
# 总结：这道题主要是考察了对字符串切片的应用。需要尤其注意两点：python中第0位和第一位的区别，以及切片符是左闭右开的。以及反思一个read().splitlines()的优势

# %%
#在DNA中寻找模体结构
with open('rosalind_subs.txt',encoding='utf-8') as f:
    a=f.readlines()
    t=a[0]
    s=a[1]
    for i in range(0,len(t)):
        if t[i:i+len(s)]==s:
            print(i+1,end=" ")#end=" "可使间隔输出
        else:
            continue
    print(type(t))
    print(t)
    print(a)
#为什么没有输出值？因为readlines输出最后都有一个/n，而print又不会显示出来！readline也是的。字符串列表
# Out:
# <class 'str'>
# ...
#
# TGGTCAGTG
# ['...\n', 'TGGTCAGTG\n']

# %%
t="..."
s="TGGTCAGTG"
for i in range(0,len(t)):
        if t[i:i+len(s)]==s:
            print(i+1,end=" ")#end=" "可使间隔输出
        else:
            continue

print(type(t))
print(t)
print(t[58:67])
# Out:
# 59 84 131 147 154 161 180 319 326 333 395 456 540 555 573 617 624 631 646 680 697 767 774 781 855 <class 'str'>
# ...
# TGGTCAGTG

# %%
#最终解决方式
with open('rosalind_subs.txt',encoding='utf-8') as f:
    a=f.read().splitlines()#所以我严重推荐使用read.splitlines方式获取字符串列表，末尾干干净净的
    t=a[0]
    s=a[1]
    for i in range(0,len(t)):
        if t[i:i+len(s)]==s:
            print(i+1,end=" ")#end=" "可使间隔输出
        else:
            continue
    
#为什么没有输出值？因为readlines输出最后都有一个/n，而print又不会显示出来！readline也是的
# Out:
# 29 62 85 132 176 245 284 311 342 383 390 397 606 632 731 758 795 824 831 846 853 862
